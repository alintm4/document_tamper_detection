# %% [markdown]
# ### Importing Datasets

# %%
import tensorflow as tf 
from tensorflow import keras

# %%
import os
from pathlib import Path

# Set base path dynamically for Jupyter Notebook
BASE_PATH = Path.cwd().parent / 'split_dataset'
print(BASE_PATH)
def load_image_dataset(directory, batch_size=32, image_size=(256, 256)):
    """
    Load image dataset from directory.
    
    Args:
        directory: Path to the dataset directory
        batch_size: Batch size for the dataset (default: 32)
        image_size: Target image size as tuple (height, width) (default: (256, 256))
    
    Returns:
        keras dataset or None if directory doesn't exist
    """
    if not os.path.exists(directory):
        print(f"Directory not found: {directory}")
        return None
    
    return keras.utils.image_dataset_from_directory(
        directory=directory,
        labels='inferred',
        label_mode='int',
        batch_size=batch_size,
        image_size=image_size
    )
# Out:
# c:\Users\sthar\abcd\techsprint_xhack\ml-app\split_dataset

# %%
# Load datasets using the function with dynamic paths
train_au_ds = load_image_dataset(str(BASE_PATH / 'train' / 'Au'))
train_tp_ds = load_image_dataset(str(BASE_PATH / 'train' / 'Tp'))
train_mask_ds = load_image_dataset(str(BASE_PATH / 'train' / 'Mask'))

test_au_ds = load_image_dataset(str(BASE_PATH / 'test' / 'Au'))
test_tp_ds = load_image_dataset(str(BASE_PATH / 'test' / 'Tp'))
test_mask_ds = load_image_dataset(str(BASE_PATH / 'test' / 'Mask'))

validation_au_ds = load_image_dataset(str(BASE_PATH / 'val' / 'Au'))
validation_tp_ds = load_image_dataset(str(BASE_PATH / 'val' / 'Tp'))
validation_mask_ds = load_image_dataset(str(BASE_PATH / 'val' / 'Mask'))
# Out:
# Found 0 files belonging to 0 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Load datasets using the function with dynamic paths
# ----> 2 train_au_ds = load_image_dataset(str(BASE_PATH / 'train' / 'Au'))
#       3 train_tp_ds = load_image_dataset(str(BASE_PATH / 'train' / 'Tp'))
#       4 train_mask_ds = load_image_dataset(str(BASE_PATH / 'train' / 'Mask'))
#
# Cell In[15], line 23, in load_image_dataset(directory, batch_size, image_size)
#      20     print(f"Directory not found: {directory}")
#      21     return None
# ---> 23 return keras.utils.image_dataset_from_directory(
#      24     directory=directory,
#      25     labels='inferred',
#      26     label_mode='int',
#      27     batch_size=batch_size,
#      28     image_size=image_size
#      29 )
#
# File c:\Users\sthar\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\image_dataset_utils.py:372, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, format, verbose)
#     368 image_paths, labels = dataset_utils.get_training_or_validation_split(
#     369     image_paths, labels, validation_split, subset
#     370 )
#     371 if not image_paths:
# --> 372     raise ValueError(
#     373         f"No images found in directory {directory}. "
#     374         f"Allowed formats: {ALLOWLIST_FORMATS}"
#     375     )
#     377 dataset = paths_and_labels_to_dataset(
#     378     image_paths=image_paths,
#     379     image_size=image_size,
#    (...)
#     391     format=format,
#     392 )
#     394 if format == "tf":
#
# ValueError: No images found in directory c:\Users\sthar\abcd\techsprint_xhack\ml-app\split_dataset\train\Au. Allowed formats: ('.bmp', '.gif', '.jpeg', '.jpg', '.png')
